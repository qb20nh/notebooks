# %%
# %matplotlib inline

# %% [markdown]
# # **PyTorch Quickstart**

# %% [markdown]
# 이번 강좌에서는 신경망의 일반적인 작업들을 위한 PyTorch API를 살펴본다.  이 강좌는 [PyTorch 공식 튜토리얼](https://pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html)의 [한글 번역본](https://tutorials.pytorch.kr/beginner/basics/quickstart_tutorial.html)을 다시 부분적으로 수정한 것이다.

# %% [markdown]
# ## 데이터 다루기

# %% [markdown]
# 파이토치(PyTorch)는 **데이터 작업을 위한 2가지 기본 요소**인
# ``torch.utils.data.DataLoader`` 와 ``torch.utils.data.Dataset``를 제공한다.
# ``Dataset``은 데이터와 정답(label)을 저장하고, ``DataLoader``는 ``Dataset``을 순회 가능한 객체(iterable)로 만들어준다.

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %% [markdown]
# PyTorch는 [`TorchText`](https://pytorch.org/text/stable/index.html), [`TorchVision`](https://pytorch.org/vision/stable/index.html) 및
# [`TorchAudio`](https://pytorch.org/audio/stable/index.html)와 같이 응용분야에 특화된 라이브러리를 다양한 데이터셋과 함께 제공한다.
# 이 강좌에서는 `TorchVision`이 제공하는 데이터셋 중에에 하나를 사용한다.
#
# ``torchvision.datasets`` 모듈은 CIFAR, COCO 등과 같은 다양한 실제 비전(vision) 데이터에 대한 ``Dataset`` (전체 목록은 [여기](https://pytorch.org/vision/stable/datasets.html)를 참조)을 포함하고 있다.
# 이 튜토리얼에서는 그 중 `FasionMNIST` 데이터셋을 사용한다.
#
#
# 모든 TorchVision ``Dataset``은 데이터와 정답을 각각 변경하기 위한 ``transform``과 ``target_transform``의 두 인자를 포함한다.

# %%
# 공개 데이터셋에서 학습 데이터를 내려받습니다.
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# 공개 데이터셋에서 테스트 데이터를 내려받습니다.
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %% [markdown]
# ``DataLoader``는 데이터셋을 순회 가능한 객체(iterable)로 감싸고(wrap), 자동화된 배치(batch), 샘플링(sampling),
# 섞기(shuffle) 및 다중 프로세스로 데이터 불러오기(multiprocess data loading)를 지원한다. 여기서는 배치 크기(batch size)를 64로 정의한다.
# 즉, 데이터로더(dataloader) 객체의 각 요소는 64개의 특징(feature)과 정답(label)을 묶음(batch)으로 반환한다.

# %%
batch_size = 64

# 데이터로더를 생성합니다.
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print("Shape of X [N, C, H, W]: {}".format(X.shape))
    print("Shape of y: {} {}".format(y.shape, y.dtype))
    break
# Out:
# Shape of X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Shape of y: torch.Size([64]) torch.int64

# %% [markdown]
# **Note:** 하나의 이미지의 `shape`이 `[1, 28, 28]`인 점에 주의하라. 보통의 Python 이미지 라이브러리에서는 이미지가 `[height, width, num_channels]`의 형태로 표현되는 것과 달리 PyTorch에서는 `[num_channels, height, width]`의 형태로 표현된다는 것을 보여준다.

# %% [markdown]
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ## 모델 만들기
#
# PyTorch에서 신경망 모델은 일반적으로 [`nn.Module`](<https://pytorch.org/docs/stable/generated/torch.nn.Module.html>)을
# 상속받는 클래스(class)를 정의하여 생성한다. ``__init__`` 함수에서 신경망의 계층(layer)들을 정의하고, ``forward`` 함수에서
# 신경망에 데이터를 어떻게 전달할지 지정한다. 가능한 경우 GPU로 신경망을 이동시켜 연산을 가속(accelerate)한다.

# %%
# 학습에 사용할 CPU나 GPU 장치를 얻습니다.
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Using {} device".format(device))

# 모델을 정의합니다.
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

model = NeuralNetwork().to(device)
print(model)
# Out:
# Using cuda device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
print(model.parameters())
for name, param in model.named_parameters():
    # if param.requires_grad:
    print(name, param.data.shape)
# Out:
# <generator object Module.parameters at 0x7f49eccbdcd0>
# linear_relu_stack.0.weight torch.Size([512, 784])
# linear_relu_stack.0.bias torch.Size([512])
# linear_relu_stack.2.weight torch.Size([512, 512])
# linear_relu_stack.2.bias torch.Size([512])
# linear_relu_stack.4.weight torch.Size([10, 512])
# linear_relu_stack.4.bias torch.Size([10])

# %% [markdown]
# ------------------------------------------------------------------------------------------

# %% [markdown]
# 모델 매개변수 최적화하기
# ------------------------------------------------------------------------------------------
# 모델을 학습하려면 [손실 함수(loss function)](<https://pytorch.org/docs/stable/nn.html#loss-functions>)와
# [옵티마이저(optimizer)](<https://pytorch.org/docs/stable/optim.html>)가 필요하다.

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-3)

# %% [markdown]
# 각 학습 단계(training loop)에서 모델은 배치(batch)로 제공되는 학습 데이터셋에 대한 예측을 수행하고,
# 예측 오류를 역전파(backpropagate)하여 모델의 매개변수를 조정한다.

# %%
def train(dataloader, model, loss_fn, optimizer):
  # maybe do model.train() here?
    size = len(dataloader.dataset)
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device) # .to() does type conversion and/or device conversion. device conversion can upload data to gpu immediately??

        # 예측 오류 계산
        pred = model(X)
        loss = loss_fn(pred, y) # pred is tensor while y is scalar, in this case pytorch automatically one-hot encodes the scalar into a tensor

        # 역전파
        optimizer.zero_grad() # 수동으로 gradient 초기화
        loss.backward() # 역전파. 레이어 별 chain rule 미분
        optimizer.step() 

        if batch % 100 == 0:
            loss, current = loss.item(), batch * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %% [markdown]
# 모델이 학습하고 있는지를 확인하기 위해 테스트 데이터셋으로 모델의 성능을 확인해보는 함수를 작성한다.

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval() # evaluation mode, changes internal behavior of some layers
    test_loss, correct = 0, 0
    with torch.no_grad(): # create a new context where grad is not evaluated automatically
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
            # pred.argmax(<axis index>) -> returns array of indices of each subarrays' max value
            # pred.argmax(...) == y -> implicit type conversion [true, false, ...]
            # .type(torch.float) -> converts to tensor true = 1, false = 0
            # .sum() adds correct count
            # .item() unwrap underlying value from tensor
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %% [markdown]
# 학습은 여러번의 반복 단계(epochs)를 거쳐서 수행된다. 각 에폭마다 모델의 정확도(accuracy)와 손실(loss)을 출력한다; 에폭마다 정확도가 증가하고 손실이 감소하는 것을 보려고 한다.

# %%
# Epoch: all data in a dataset was used once
epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train(train_dataloader, model, loss_fn, optimizer)
    test(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.305583  [    0/60000]
# loss: 2.291343  [ 6400/60000]
# loss: 2.272291  [12800/60000]
# loss: 2.266457  [19200/60000]
# loss: 2.244849  [25600/60000]
# loss: 2.214673  [32000/60000]
# loss: 2.233756  [38400/60000]
# loss: 2.194694  [44800/60000]
# loss: 2.186348  [51200/60000]
# loss: 2.160175  [57600/60000]
# Test Error:
#  Accuracy: 36.5%, Avg loss: 2.147735
#
# Epoch 2
# -------------------------------
# loss: 2.162927  [    0/60000]
# loss: 2.154694  [ 6400/60000]
# loss: 2.096610  [12800/60000]
# loss: 2.114064  [19200/60000]
# loss: 2.062675  [25600/60000]
# loss: 2.001923  [32000/60000]
# loss: 2.037738  [38400/60000]
# loss: 1.955653  [44800/60000]
# loss: 1.958507  [51200/60000]
# loss: 1.894508  [57600/60000]
# Test Error:
#  Accuracy: 53.2%, Avg loss: 1.884619
#
# Epoch 3
# -------------------------------
# loss: 1.922693  [    0/60000]
# loss: 1.899830  [ 6400/60000]
# loss: 1.775839  [12800/60000]
# loss: 1.818809  [19200/60000]
# loss: 1.706788  [25600/60000]
# loss: 1.661557  [32000/60000]
# loss: 1.684948  [38400/60000]
# loss: 1.581765  [44800/60000]
# loss: 1.607201  [51200/60000]
# loss: 1.503960  [57600/60000]
# Test Error:
#  Accuracy: 60.7%, Avg loss: 1.513303
#
# Epoch 4
# -------------------------------
# loss: 1.585084  [    0/60000]
# loss: 1.555183  [ 6400/60000]
# loss: 1.396192  [12800/60000]
# loss: 1.472011  [19200/60000]
# loss: 1.343061  [25600/60000]
# loss: 1.343170  [32000/60000]
# loss: 1.360446  [38400/60000]
# loss: 1.279526  [44800/60000]
# loss: 1.320895  [51200/60000]
# loss: 1.221744  [57600/60000]
# Test Error:
#  Accuracy: 63.5%, Avg loss: 1.240670
#
# Epoch 5
# -------------------------------
# loss: 1.319796  [    0/60000]
# loss: 1.305669  [ 6400/60000]
# loss: 1.136054  [12800/60000]
# loss: 1.246356  [19200/60000]
# loss: 1.110043  [25600/60000]
# loss: 1.140160  [32000/60000]
# loss: 1.165999  [38400/60000]
# loss: 1.097871  [44800/60000]
# loss: 1.145303  [51200/60000]
# loss: 1.060935  [57600/60000]
# Test Error:
#  Accuracy: 64.9%, Avg loss: 1.075452
#
# Epoch 6
# -------------------------------
# loss: 1.145749  [    0/60000]
# loss: 1.151470  [ 6400/60000]
# loss: 0.969231  [12800/60000]
# loss: 1.107562  [19200/60000]
# loss: 0.969216  [25600/60000]
# loss: 1.007264  [32000/60000]
# loss: 1.047987  [38400/60000]
# loss: 0.987152  [44800/60000]
# loss: 1.033938  [51200/60000]
# loss: 0.960856  [57600/60000]
# Test Error:
#  Accuracy: 66.0%, Avg loss: 0.970773
#
# Epoch 7
# -------------------------------
# loss: 1.028439  [    0/60000]
# loss: 1.052366  [ 6400/60000]
# loss: 0.857510  [12800/60000]
# loss: 1.016197  [19200/60000]
# loss: 0.882310  [25600/60000]
# loss: 0.915262  [32000/60000]
# loss: 0.971569  [38400/60000]
# loss: 0.916948  [44800/60000]
# loss: 0.958336  [51200/60000]
# loss: 0.894086  [57600/60000]
# Test Error:
#  Accuracy: 67.4%, Avg loss: 0.900295
#
# Epoch 8
# -------------------------------
# loss: 0.943720  [    0/60000]
# loss: 0.983738  [ 6400/60000]
# loss: 0.778827  [12800/60000]
# loss: 0.952207  [19200/60000]
# loss: 0.825542  [25600/60000]
# loss: 0.848707  [32000/60000]
# loss: 0.917882  [38400/60000]
# loss: 0.870639  [44800/60000]
# loss: 0.904242  [51200/60000]
# loss: 0.846215  [57600/60000]
# Test Error:
#  Accuracy: 68.6%, Avg loss: 0.849884
#
# Epoch 9
# -------------------------------
# loss: 0.878770  [    0/60000]
# loss: 0.932643  [ 6400/60000]
# loss: 0.720129  [12800/60000]
# loss: 0.905080  [19200/60000]
# loss: 0.785852  [25600/60000]
# loss: 0.798741  [32000/60000]
# loss: 0.877083  [38400/60000]
# loss: 0.838393  [44800/60000]
# loss: 0.863684  [51200/60000]
# loss: 0.809800  [57600/60000]
# Test Error:
#  Accuracy: 69.8%, Avg loss: 0.811743
#
# Epoch 10
# -------------------------------
# loss: 0.826625  [    0/60000]
# loss: 0.892280  [ 6400/60000]
# loss: 0.674098  [12800/60000]
# loss: 0.869081  [19200/60000]
# loss: 0.756249  [25600/60000]
# loss: 0.760035  [32000/60000]
# loss: 0.843984  [38400/60000]
# loss: 0.814407  [44800/60000]
# loss: 0.831871  [51200/60000]
# loss: 0.780727  [57600/60000]
# Test Error:
#  Accuracy: 71.1%, Avg loss: 0.781416
#
# Epoch 11
# -------------------------------
# loss: 0.783334  [    0/60000]
# loss: 0.858658  [ 6400/60000]
# loss: 0.636967  [12800/60000]
# loss: 0.840668  [19200/60000]
# loss: 0.732946  [25600/60000]
# loss: 0.729331  [32000/60000]
# loss: 0.815718  [38400/60000]
# loss: 0.795181  [44800/60000]
# loss: 0.805673  [51200/60000]
# loss: 0.756448  [57600/60000]
# Test Error:
#  Accuracy: 72.3%, Avg loss: 0.756222
#
# Epoch 12
# -------------------------------
# loss: 0.746463  [    0/60000]
# loss: 0.829586  [ 6400/60000]
# loss: 0.605981  [12800/60000]
# loss: 0.817512  [19200/60000]
# loss: 0.713745  [25600/60000]
# loss: 0.704519  [32000/60000]
# loss: 0.790741  [38400/60000]
# loss: 0.778949  [44800/60000]
# loss: 0.783614  [51200/60000]
# loss: 0.735267  [57600/60000]
# Test Error:
#  Accuracy: 73.4%, Avg loss: 0.734521
#
# Epoch 13
# -------------------------------
# loss: 0.714375  [    0/60000]
# loss: 0.803757  [ 6400/60000]
# loss: 0.579492  [12800/60000]
# loss: 0.797927  [19200/60000]
# loss: 0.697197  [25600/60000]
# loss: 0.683932  [32000/60000]
# loss: 0.767971  [38400/60000]
# loss: 0.764573  [44800/60000]
# loss: 0.764523  [51200/60000]
# loss: 0.716460  [57600/60000]
# Test Error:
#  Accuracy: 74.3%, Avg loss: 0.715304
#
# Epoch 14
# -------------------------------
# loss: 0.685893  [    0/60000]
# loss: 0.780309  [ 6400/60000]
# loss: 0.556327  [12800/60000]
# loss: 0.780853  [19200/60000]
# loss: 0.682730  [25600/60000]
# loss: 0.666532  [32000/60000]
# loss: 0.747005  [38400/60000]
# loss: 0.751489  [44800/60000]
# loss: 0.747546  [51200/60000]
# loss: 0.699418  [57600/60000]
# Test Error:
#  Accuracy: 75.0%, Avg loss: 0.697941
#
# Epoch 15
# -------------------------------
# loss: 0.660352  [    0/60000]
# loss: 0.758732  [ 6400/60000]
# loss: 0.535779  [12800/60000]
# loss: 0.765668  [19200/60000]
# loss: 0.669841  [25600/60000]
# loss: 0.651486  [32000/60000]
# loss: 0.727513  [38400/60000]
# loss: 0.739433  [44800/60000]
# loss: 0.732375  [51200/60000]
# loss: 0.683821  [57600/60000]
# Test Error:
#  Accuracy: 75.9%, Avg loss: 0.682058
#
# Epoch 16
# -------------------------------
# loss: 0.637340  [    0/60000]
# loss: 0.738907  [ 6400/60000]
# loss: 0.517458  [12800/60000]
# loss: 0.751870  [19200/60000]
# loss: 0.658412  [25600/60000]
# loss: 0.638442  [32000/60000]
# loss: 0.709377  [38400/60000]
# loss: 0.728304  [44800/60000]
# loss: 0.718835  [51200/60000]
# loss: 0.669385  [57600/60000]
# Test Error:
#  Accuracy: 76.6%, Avg loss: 0.667427
#
# Epoch 17
# -------------------------------
# loss: 0.616582  [    0/60000]
# loss: 0.720618  [ 6400/60000]
# loss: 0.500936  [12800/60000]
# loss: 0.739237  [19200/60000]
# loss: 0.648208  [25600/60000]
# loss: 0.626988  [32000/60000]
# loss: 0.692440  [38400/60000]
# loss: 0.718179  [44800/60000]
# loss: 0.706692  [51200/60000]
# loss: 0.655925  [57600/60000]
# Test Error:
#  Accuracy: 77.2%, Avg loss: 0.653912
#
# Epoch 18
# -------------------------------
# loss: 0.597767  [    0/60000]
# loss: 0.703678  [ 6400/60000]
# loss: 0.486047  [12800/60000]
# loss: 0.727495  [19200/60000]
# loss: 0.639037  [25600/60000]
# loss: 0.616789  [32000/60000]
# loss: 0.676628  [38400/60000]
# loss: 0.709040  [44800/60000]
# loss: 0.695862  [51200/60000]
# loss: 0.643342  [57600/60000]
# Test Error:
#  Accuracy: 77.7%, Avg loss: 0.641416
#
# Epoch 19
# -------------------------------
# loss: 0.580680  [    0/60000]
# loss: 0.687981  [ 6400/60000]
# loss: 0.472538  [12800/60000]
# loss: 0.716547  [19200/60000]
# loss: 0.630758  [25600/60000]
# loss: 0.607664  [32000/60000]
# loss: 0.661942  [38400/60000]
# loss: 0.700973  [44800/60000]
# loss: 0.686296  [51200/60000]
# loss: 0.631469  [57600/60000]
# Test Error:
#  Accuracy: 78.3%, Avg loss: 0.629863
#
# Epoch 20
# -------------------------------
# loss: 0.565132  [    0/60000]
# loss: 0.673452  [ 6400/60000]
# loss: 0.460234  [12800/60000]
# loss: 0.706319  [19200/60000]
# loss: 0.623227  [25600/60000]
# loss: 0.599433  [32000/60000]
# loss: 0.648358  [38400/60000]
# loss: 0.693943  [44800/60000]
# loss: 0.677891  [51200/60000]
# loss: 0.620258  [57600/60000]
# Test Error:
#  Accuracy: 78.6%, Avg loss: 0.619184
#
# Epoch 21
# -------------------------------
# loss: 0.550890  [    0/60000]
# loss: 0.660056  [ 6400/60000]
# loss: 0.449035  [12800/60000]
# loss: 0.696692  [19200/60000]
# loss: 0.616285  [25600/60000]
# loss: 0.591982  [32000/60000]
# loss: 0.635720  [38400/60000]
# loss: 0.687960  [44800/60000]
# loss: 0.670507  [51200/60000]
# loss: 0.609585  [57600/60000]
# Test Error:
#  Accuracy: 79.0%, Avg loss: 0.609314
#
# Epoch 22
# -------------------------------
# loss: 0.537827  [    0/60000]
# loss: 0.647703  [ 6400/60000]
# loss: 0.438784  [12800/60000]
# loss: 0.687581  [19200/60000]
# loss: 0.609718  [25600/60000]
# loss: 0.585130  [32000/60000]
# loss: 0.624045  [38400/60000]
# loss: 0.682921  [44800/60000]
# loss: 0.664166  [51200/60000]
# loss: 0.599354  [57600/60000]
# Test Error:
#  Accuracy: 79.3%, Avg loss: 0.600193
#
# Epoch 23
# -------------------------------
# loss: 0.525778  [    0/60000]
# loss: 0.636312  [ 6400/60000]
# loss: 0.429305  [12800/60000]
# loss: 0.678921  [19200/60000]
# loss: 0.603487  [25600/60000]
# loss: 0.578764  [32000/60000]
# loss: 0.613288  [38400/60000]
# loss: 0.678767  [44800/60000]
# loss: 0.658710  [51200/60000]
# loss: 0.589568  [57600/60000]
# Test Error:
#  Accuracy: 79.6%, Avg loss: 0.591761
#
# Epoch 24
# -------------------------------
# loss: 0.514645  [    0/60000]
# loss: 0.625743  [ 6400/60000]
# loss: 0.420541  [12800/60000]
# loss: 0.670681  [19200/60000]
# loss: 0.597510  [25600/60000]
# loss: 0.572829  [32000/60000]
# loss: 0.603321  [38400/60000]
# loss: 0.675478  [44800/60000]
# loss: 0.654023  [51200/60000]
# loss: 0.580131  [57600/60000]
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.583953
#
# Epoch 25
# -------------------------------
# loss: 0.504307  [    0/60000]
# loss: 0.616017  [ 6400/60000]
# loss: 0.412425  [12800/60000]
# loss: 0.662913  [19200/60000]
# loss: 0.591761  [25600/60000]
# loss: 0.567211  [32000/60000]
# loss: 0.594107  [38400/60000]
# loss: 0.673004  [44800/60000]
# loss: 0.649925  [51200/60000]
# loss: 0.570956  [57600/60000]
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.576719
#
# Epoch 26
# -------------------------------
# loss: 0.494594  [    0/60000]
# loss: 0.607015  [ 6400/60000]
# loss: 0.404880  [12800/60000]
# loss: 0.655518  [19200/60000]
# loss: 0.586163  [25600/60000]
# loss: 0.561883  [32000/60000]
# loss: 0.585603  [38400/60000]
# loss: 0.671228  [44800/60000]
# loss: 0.646363  [51200/60000]
# loss: 0.562102  [57600/60000]
# Test Error:
#  Accuracy: 80.2%, Avg loss: 0.570015
#
# Epoch 27
# -------------------------------
# loss: 0.485471  [    0/60000]
# loss: 0.598732  [ 6400/60000]
# loss: 0.397876  [12800/60000]
# loss: 0.648501  [19200/60000]
# loss: 0.580671  [25600/60000]
# loss: 0.556709  [32000/60000]
# loss: 0.577705  [38400/60000]
# loss: 0.670031  [44800/60000]
# loss: 0.643237  [51200/60000]
# loss: 0.553494  [57600/60000]
# Test Error:
#  Accuracy: 80.5%, Avg loss: 0.563784
#
# Epoch 28
# -------------------------------
# loss: 0.476909  [    0/60000]
# loss: 0.591074  [ 6400/60000]
# loss: 0.391324  [12800/60000]
# loss: 0.641814  [19200/60000]
# loss: 0.575212  [25600/60000]
# loss: 0.551703  [32000/60000]
# loss: 0.570365  [38400/60000]
# loss: 0.669348  [44800/60000]
# loss: 0.640488  [51200/60000]
# loss: 0.545185  [57600/60000]
# Test Error:
#  Accuracy: 80.6%, Avg loss: 0.557990
#
# Epoch 29
# -------------------------------
# loss: 0.468812  [    0/60000]
# loss: 0.584006  [ 6400/60000]
# loss: 0.385229  [12800/60000]
# loss: 0.635513  [19200/60000]
# loss: 0.569776  [25600/60000]
# loss: 0.546789  [32000/60000]
# loss: 0.563582  [38400/60000]
# loss: 0.669097  [44800/60000]
# loss: 0.638106  [51200/60000]
# loss: 0.537135  [57600/60000]
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.552595
#
# Epoch 30
# -------------------------------
# loss: 0.461160  [    0/60000]
# loss: 0.577460  [ 6400/60000]
# loss: 0.379519  [12800/60000]
# loss: 0.629475  [19200/60000]
# loss: 0.564263  [25600/60000]
# loss: 0.541943  [32000/60000]
# loss: 0.557282  [38400/60000]
# loss: 0.669124  [44800/60000]
# loss: 0.635886  [51200/60000]
# loss: 0.529332  [57600/60000]
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.547558
#
# Epoch 31
# -------------------------------
# loss: 0.453899  [    0/60000]
# loss: 0.571478  [ 6400/60000]
# loss: 0.374195  [12800/60000]
# loss: 0.623712  [19200/60000]
# loss: 0.558827  [25600/60000]
# loss: 0.537164  [32000/60000]
# loss: 0.551414  [38400/60000]
# loss: 0.669288  [44800/60000]
# loss: 0.633772  [51200/60000]
# loss: 0.521724  [57600/60000]
# Test Error:
#  Accuracy: 81.0%, Avg loss: 0.542844
#
# Epoch 32
# -------------------------------
# loss: 0.446973  [    0/60000]
# loss: 0.565919  [ 6400/60000]
# loss: 0.369204  [12800/60000]
# loss: 0.618200  [19200/60000]
# loss: 0.553409  [25600/60000]
# loss: 0.532489  [32000/60000]
# loss: 0.545978  [38400/60000]
# loss: 0.669629  [44800/60000]
# loss: 0.631824  [51200/60000]
# loss: 0.514438  [57600/60000]
# Test Error:
#  Accuracy: 81.1%, Avg loss: 0.538434
#
# Epoch 33
# -------------------------------
# loss: 0.440291  [    0/60000]
# loss: 0.560746  [ 6400/60000]
# loss: 0.364496  [12800/60000]
# loss: 0.612924  [19200/60000]
# loss: 0.548086  [25600/60000]
# loss: 0.527899  [32000/60000]
# loss: 0.540886  [38400/60000]
# loss: 0.670136  [44800/60000]
# loss: 0.629947  [51200/60000]
# loss: 0.507401  [57600/60000]
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.534294
#
# Epoch 34
# -------------------------------
# loss: 0.433913  [    0/60000]
# loss: 0.555911  [ 6400/60000]
# loss: 0.360009  [12800/60000]
# loss: 0.607862  [19200/60000]
# loss: 0.542795  [25600/60000]
# loss: 0.523445  [32000/60000]
# loss: 0.536107  [38400/60000]
# loss: 0.670698  [44800/60000]
# loss: 0.628189  [51200/60000]
# loss: 0.500630  [57600/60000]
# Test Error:
#  Accuracy: 81.4%, Avg loss: 0.530402
#
# Epoch 35
# -------------------------------
# loss: 0.427798  [    0/60000]
# loss: 0.551402  [ 6400/60000]
# loss: 0.355802  [12800/60000]
# loss: 0.602985  [19200/60000]
# loss: 0.537589  [25600/60000]
# loss: 0.519098  [32000/60000]
# loss: 0.531576  [38400/60000]
# loss: 0.671291  [44800/60000]
# loss: 0.626450  [51200/60000]
# loss: 0.494099  [57600/60000]
# Test Error:
#  Accuracy: 81.6%, Avg loss: 0.526735
#
# Epoch 36
# -------------------------------
# loss: 0.421931  [    0/60000]
# loss: 0.547217  [ 6400/60000]
# loss: 0.351827  [12800/60000]
# loss: 0.598269  [19200/60000]
# loss: 0.532485  [25600/60000]
# loss: 0.514861  [32000/60000]
# loss: 0.527323  [38400/60000]
# loss: 0.671829  [44800/60000]
# loss: 0.624758  [51200/60000]
# loss: 0.487844  [57600/60000]
# Test Error:
#  Accuracy: 81.7%, Avg loss: 0.523277
#
# Epoch 37
# -------------------------------
# loss: 0.416322  [    0/60000]
# loss: 0.543312  [ 6400/60000]
# loss: 0.348080  [12800/60000]
# loss: 0.593721  [19200/60000]
# loss: 0.527494  [25600/60000]
# loss: 0.510662  [32000/60000]
# loss: 0.523328  [38400/60000]
# loss: 0.672341  [44800/60000]
# loss: 0.623070  [51200/60000]
# loss: 0.481915  [57600/60000]
# Test Error:
#  Accuracy: 81.8%, Avg loss: 0.520004
#
# Epoch 38
# -------------------------------
# loss: 0.410909  [    0/60000]
# loss: 0.539671  [ 6400/60000]
# loss: 0.344535  [12800/60000]
# loss: 0.589324  [19200/60000]
# loss: 0.522551  [25600/60000]
# loss: 0.506550  [32000/60000]
# loss: 0.519530  [38400/60000]
# loss: 0.672781  [44800/60000]
# loss: 0.621423  [51200/60000]
# loss: 0.476250  [57600/60000]
# Test Error:
#  Accuracy: 81.9%, Avg loss: 0.516904
#
# Epoch 39
# -------------------------------
# loss: 0.405696  [    0/60000]
# loss: 0.536230  [ 6400/60000]
# loss: 0.341157  [12800/60000]
# loss: 0.585047  [19200/60000]
# loss: 0.517722  [25600/60000]
# loss: 0.502479  [32000/60000]
# loss: 0.515864  [38400/60000]
# loss: 0.673103  [44800/60000]
# loss: 0.619766  [51200/60000]
# loss: 0.470868  [57600/60000]
# Test Error:
#  Accuracy: 82.0%, Avg loss: 0.513968
#
# Epoch 40
# -------------------------------
# loss: 0.400614  [    0/60000]
# loss: 0.532983  [ 6400/60000]
# loss: 0.337976  [12800/60000]
# loss: 0.580935  [19200/60000]
# loss: 0.512992  [25600/60000]
# loss: 0.498496  [32000/60000]
# loss: 0.512380  [38400/60000]
# loss: 0.673293  [44800/60000]
# loss: 0.618185  [51200/60000]
# loss: 0.465703  [57600/60000]
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.511180
#
# Epoch 41
# -------------------------------
# loss: 0.395700  [    0/60000]
# loss: 0.529885  [ 6400/60000]
# loss: 0.334932  [12800/60000]
# loss: 0.576945  [19200/60000]
# loss: 0.508401  [25600/60000]
# loss: 0.494656  [32000/60000]
# loss: 0.509038  [38400/60000]
# loss: 0.673314  [44800/60000]
# loss: 0.616539  [51200/60000]
# loss: 0.460817  [57600/60000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.508525
#
# Epoch 42
# -------------------------------
# loss: 0.390948  [    0/60000]
# loss: 0.526990  [ 6400/60000]
# loss: 0.332031  [12800/60000]
# loss: 0.573109  [19200/60000]
# loss: 0.503930  [25600/60000]
# loss: 0.490936  [32000/60000]
# loss: 0.505891  [38400/60000]
# loss: 0.673213  [44800/60000]
# loss: 0.614902  [51200/60000]
# loss: 0.456189  [57600/60000]
# Test Error:
#  Accuracy: 82.2%, Avg loss: 0.505996
#
# Epoch 43
# -------------------------------
# loss: 0.386346  [    0/60000]
# loss: 0.524268  [ 6400/60000]
# loss: 0.329248  [12800/60000]
# loss: 0.569399  [19200/60000]
# loss: 0.499630  [25600/60000]
# loss: 0.487308  [32000/60000]
# loss: 0.502902  [38400/60000]
# loss: 0.672955  [44800/60000]
# loss: 0.613291  [51200/60000]
# loss: 0.451760  [57600/60000]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.503579
#
# Epoch 44
# -------------------------------
# loss: 0.381895  [    0/60000]
# loss: 0.521723  [ 6400/60000]
# loss: 0.326540  [12800/60000]
# loss: 0.565795  [19200/60000]
# loss: 0.495442  [25600/60000]
# loss: 0.483776  [32000/60000]
# loss: 0.500074  [38400/60000]
# loss: 0.672525  [44800/60000]
# loss: 0.611641  [51200/60000]
# loss: 0.447571  [57600/60000]
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.501268
#
# Epoch 45
# -------------------------------
# loss: 0.377595  [    0/60000]
# loss: 0.519297  [ 6400/60000]
# loss: 0.323938  [12800/60000]
# loss: 0.562348  [19200/60000]
# loss: 0.491354  [25600/60000]
# loss: 0.480335  [32000/60000]
# loss: 0.497296  [38400/60000]
# loss: 0.671973  [44800/60000]
# loss: 0.609996  [51200/60000]
# loss: 0.443616  [57600/60000]
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.499055
#
# Epoch 46
# -------------------------------
# loss: 0.373400  [    0/60000]
# loss: 0.516995  [ 6400/60000]
# loss: 0.321418  [12800/60000]
# loss: 0.559013  [19200/60000]
# loss: 0.487405  [25600/60000]
# loss: 0.477005  [32000/60000]
# loss: 0.494633  [38400/60000]
# loss: 0.671261  [44800/60000]
# loss: 0.608266  [51200/60000]
# loss: 0.439848  [57600/60000]
# Test Error:
#  Accuracy: 82.5%, Avg loss: 0.496933
#
# Epoch 47
# -------------------------------
# loss: 0.369363  [    0/60000]
# loss: 0.514809  [ 6400/60000]
# loss: 0.318975  [12800/60000]
# loss: 0.555816  [19200/60000]
# loss: 0.483601  [25600/60000]
# loss: 0.473776  [32000/60000]
# loss: 0.492099  [38400/60000]
# loss: 0.670398  [44800/60000]
# loss: 0.606556  [51200/60000]
# loss: 0.436343  [57600/60000]
# Test Error:
#  Accuracy: 82.6%, Avg loss: 0.494896
#
# Epoch 48
# -------------------------------
# loss: 0.365465  [    0/60000]
# loss: 0.512694  [ 6400/60000]
# loss: 0.316644  [12800/60000]
# loss: 0.552696  [19200/60000]
# loss: 0.479858  [25600/60000]
# loss: 0.470651  [32000/60000]
# loss: 0.489612  [38400/60000]
# loss: 0.669398  [44800/60000]
# loss: 0.604887  [51200/60000]
# loss: 0.433024  [57600/60000]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.492937
#
# Epoch 49
# -------------------------------
# loss: 0.361644  [    0/60000]
# loss: 0.510667  [ 6400/60000]
# loss: 0.314410  [12800/60000]
# loss: 0.549659  [19200/60000]
# loss: 0.476258  [25600/60000]
# loss: 0.467638  [32000/60000]
# loss: 0.487236  [38400/60000]
# loss: 0.668322  [44800/60000]
# loss: 0.603175  [51200/60000]
# loss: 0.429858  [57600/60000]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.491054
#
# Epoch 50
# -------------------------------
# loss: 0.357929  [    0/60000]
# loss: 0.508730  [ 6400/60000]
# loss: 0.312253  [12800/60000]
# loss: 0.546732  [19200/60000]
# loss: 0.472744  [25600/60000]
# loss: 0.464753  [32000/60000]
# loss: 0.484918  [38400/60000]
# loss: 0.667136  [44800/60000]
# loss: 0.601470  [51200/60000]
# loss: 0.426884  [57600/60000]
# Test Error:
#  Accuracy: 82.7%, Avg loss: 0.489238
#
# Epoch 51
# -------------------------------
# loss: 0.354254  [    0/60000]
# loss: 0.506843  [ 6400/60000]
# loss: 0.310144  [12800/60000]
# loss: 0.543913  [19200/60000]
# loss: 0.469322  [25600/60000]
# loss: 0.462038  [32000/60000]
# loss: 0.482703  [38400/60000]
# loss: 0.665850  [44800/60000]
# loss: 0.599771  [51200/60000]
# loss: 0.423993  [57600/60000]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.487480
#
# Epoch 52
# -------------------------------
# loss: 0.350700  [    0/60000]
# loss: 0.505005  [ 6400/60000]
# loss: 0.308154  [12800/60000]
# loss: 0.541214  [19200/60000]
# loss: 0.465986  [25600/60000]
# loss: 0.459334  [32000/60000]
# loss: 0.480537  [38400/60000]
# loss: 0.664482  [44800/60000]
# loss: 0.598088  [51200/60000]
# loss: 0.421292  [57600/60000]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.485784
#
# Epoch 53
# -------------------------------
# loss: 0.347276  [    0/60000]
# loss: 0.503258  [ 6400/60000]
# loss: 0.306216  [12800/60000]
# loss: 0.538655  [19200/60000]
# loss: 0.462673  [25600/60000]
# loss: 0.456727  [32000/60000]
# loss: 0.478448  [38400/60000]
# loss: 0.663038  [44800/60000]
# loss: 0.596478  [51200/60000]
# loss: 0.418747  [57600/60000]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.484144
#
# Epoch 54
# -------------------------------
# loss: 0.343970  [    0/60000]
# loss: 0.501520  [ 6400/60000]
# loss: 0.304349  [12800/60000]
# loss: 0.536229  [19200/60000]
# loss: 0.459429  [25600/60000]
# loss: 0.454229  [32000/60000]
# loss: 0.476381  [38400/60000]
# loss: 0.661499  [44800/60000]
# loss: 0.594877  [51200/60000]
# loss: 0.416407  [57600/60000]
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.482561
#
# Epoch 55
# -------------------------------
# loss: 0.340779  [    0/60000]
# loss: 0.499783  [ 6400/60000]
# loss: 0.302528  [12800/60000]
# loss: 0.533905  [19200/60000]
# loss: 0.456302  [25600/60000]
# loss: 0.451835  [32000/60000]
# loss: 0.474389  [38400/60000]
# loss: 0.659900  [44800/60000]
# loss: 0.593237  [51200/60000]
# loss: 0.414176  [57600/60000]
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.481028
#
# Epoch 56
# -------------------------------
# loss: 0.337683  [    0/60000]
# loss: 0.498087  [ 6400/60000]
# loss: 0.300729  [12800/60000]
# loss: 0.531633  [19200/60000]
# loss: 0.453229  [25600/60000]
# loss: 0.449523  [32000/60000]
# loss: 0.472436  [38400/60000]
# loss: 0.658228  [44800/60000]
# loss: 0.591645  [51200/60000]
# loss: 0.412084  [57600/60000]
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.479542
#
# Epoch 57
# -------------------------------
# loss: 0.334700  [    0/60000]
# loss: 0.496404  [ 6400/60000]
# loss: 0.298967  [12800/60000]
# loss: 0.529452  [19200/60000]
# loss: 0.450288  [25600/60000]
# loss: 0.447254  [32000/60000]
# loss: 0.470567  [38400/60000]
# loss: 0.656526  [44800/60000]
# loss: 0.590042  [51200/60000]
# loss: 0.410099  [57600/60000]
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.478104
#
# Epoch 58
# -------------------------------
# loss: 0.331796  [    0/60000]
# loss: 0.494741  [ 6400/60000]
# loss: 0.297243  [12800/60000]
# loss: 0.527342  [19200/60000]
# loss: 0.447403  [25600/60000]
# loss: 0.445090  [32000/60000]
# loss: 0.468712  [38400/60000]
# loss: 0.654806  [44800/60000]
# loss: 0.588474  [51200/60000]
# loss: 0.408240  [57600/60000]
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.476706
#
# Epoch 59
# -------------------------------
# loss: 0.329000  [    0/60000]
# loss: 0.493076  [ 6400/60000]
# loss: 0.295588  [12800/60000]
# loss: 0.525278  [19200/60000]
# loss: 0.444610  [25600/60000]
# loss: 0.443011  [32000/60000]
# loss: 0.466869  [38400/60000]
# loss: 0.653068  [44800/60000]
# loss: 0.586805  [51200/60000]
# loss: 0.406461  [57600/60000]
# Test Error:
#  Accuracy: 83.0%, Avg loss: 0.475346
#
# Epoch 60
# -------------------------------
# loss: 0.326314  [    0/60000]
# loss: 0.491438  [ 6400/60000]
# loss: 0.293964  [12800/60000]
# loss: 0.523255  [19200/60000]
# loss: 0.441929  [25600/60000]
# loss: 0.440968  [32000/60000]
# loss: 0.465090  [38400/60000]
# loss: 0.651255  [44800/60000]
# loss: 0.585219  [51200/60000]
# loss: 0.404809  [57600/60000]
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.474015
#
# Epoch 61
# -------------------------------
# loss: 0.323703  [    0/60000]
# loss: 0.489810  [ 6400/60000]
# loss: 0.292417  [12800/60000]
# loss: 0.521360  [19200/60000]
# loss: 0.439265  [25600/60000]
# loss: 0.439049  [32000/60000]
# loss: 0.463399  [38400/60000]
# loss: 0.649451  [44800/60000]
# loss: 0.583638  [51200/60000]
# loss: 0.403264  [57600/60000]
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.472719
#
# Epoch 62
# -------------------------------
# loss: 0.321133  [    0/60000]
# loss: 0.488228  [ 6400/60000]
# loss: 0.290916  [12800/60000]
# loss: 0.519550  [19200/60000]
# loss: 0.436644  [25600/60000]
# loss: 0.437207  [32000/60000]
# loss: 0.461762  [38400/60000]
# loss: 0.647672  [44800/60000]
# loss: 0.582007  [51200/60000]
# loss: 0.401803  [57600/60000]
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.471451
#
# Epoch 63
# -------------------------------
# loss: 0.318661  [    0/60000]
# loss: 0.486676  [ 6400/60000]
# loss: 0.289511  [12800/60000]
# loss: 0.517816  [19200/60000]
# loss: 0.434021  [25600/60000]
# loss: 0.435383  [32000/60000]
# loss: 0.460144  [38400/60000]
# loss: 0.645878  [44800/60000]
# loss: 0.580457  [51200/60000]
# loss: 0.400385  [57600/60000]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.470209
#
# Epoch 64
# -------------------------------
# loss: 0.316278  [    0/60000]
# loss: 0.485137  [ 6400/60000]
# loss: 0.288156  [12800/60000]
# loss: 0.516099  [19200/60000]
# loss: 0.431372  [25600/60000]
# loss: 0.433645  [32000/60000]
# loss: 0.458528  [38400/60000]
# loss: 0.644072  [44800/60000]
# loss: 0.578977  [51200/60000]
# loss: 0.399044  [57600/60000]
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.469004
#
# Epoch 65
# -------------------------------
# loss: 0.313926  [    0/60000]
# loss: 0.483623  [ 6400/60000]
# loss: 0.286836  [12800/60000]
# loss: 0.514460  [19200/60000]
# loss: 0.428822  [25600/60000]
# loss: 0.431959  [32000/60000]
# loss: 0.456974  [38400/60000]
# loss: 0.642375  [44800/60000]
# loss: 0.577491  [51200/60000]
# loss: 0.397780  [57600/60000]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.467828
#
# Epoch 66
# -------------------------------
# loss: 0.311651  [    0/60000]
# loss: 0.482125  [ 6400/60000]
# loss: 0.285583  [12800/60000]
# loss: 0.512876  [19200/60000]
# loss: 0.426406  [25600/60000]
# loss: 0.430305  [32000/60000]
# loss: 0.455487  [38400/60000]
# loss: 0.640672  [44800/60000]
# loss: 0.576032  [51200/60000]
# loss: 0.396553  [57600/60000]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.466674
#
# Epoch 67
# -------------------------------
# loss: 0.309440  [    0/60000]
# loss: 0.480681  [ 6400/60000]
# loss: 0.284403  [12800/60000]
# loss: 0.511316  [19200/60000]
# loss: 0.424090  [25600/60000]
# loss: 0.428689  [32000/60000]
# loss: 0.454074  [38400/60000]
# loss: 0.639014  [44800/60000]
# loss: 0.574609  [51200/60000]
# loss: 0.395375  [57600/60000]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.465545
#
# Epoch 68
# -------------------------------
# loss: 0.307251  [    0/60000]
# loss: 0.479233  [ 6400/60000]
# loss: 0.283268  [12800/60000]
# loss: 0.509828  [19200/60000]
# loss: 0.421861  [25600/60000]
# loss: 0.427038  [32000/60000]
# loss: 0.452683  [38400/60000]
# loss: 0.637340  [44800/60000]
# loss: 0.573095  [51200/60000]
# loss: 0.394210  [57600/60000]
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.464434
#
# Epoch 69
# -------------------------------
# loss: 0.305185  [    0/60000]
# loss: 0.477798  [ 6400/60000]
# loss: 0.282107  [12800/60000]
# loss: 0.508413  [19200/60000]
# loss: 0.419653  [25600/60000]
# loss: 0.425467  [32000/60000]
# loss: 0.451336  [38400/60000]
# loss: 0.635644  [44800/60000]
# loss: 0.571655  [51200/60000]
# loss: 0.393108  [57600/60000]
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.463345
#
# Epoch 70
# -------------------------------
# loss: 0.303168  [    0/60000]
# loss: 0.476378  [ 6400/60000]
# loss: 0.280907  [12800/60000]
# loss: 0.507027  [19200/60000]
# loss: 0.417465  [25600/60000]
# loss: 0.423969  [32000/60000]
# loss: 0.449971  [38400/60000]
# loss: 0.633966  [44800/60000]
# loss: 0.570275  [51200/60000]
# loss: 0.392077  [57600/60000]
# Test Error:
#  Accuracy: 83.4%, Avg loss: 0.462289
#
# Epoch 71
# -------------------------------
# loss: 0.301260  [    0/60000]
# loss: 0.474929  [ 6400/60000]
# loss: 0.279697  [12800/60000]
# loss: 0.505624  [19200/60000]
# loss: 0.415325  [25600/60000]
# loss: 0.422532  [32000/60000]
# loss: 0.448590  [38400/60000]
# loss: 0.632298  [44800/60000]
# loss: 0.568827  [51200/60000]
# loss: 0.391078  [57600/60000]
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.461237
#
# Epoch 72
# -------------------------------
# loss: 0.299369  [    0/60000]
# loss: 0.473388  [ 6400/60000]
# loss: 0.278543  [12800/60000]
# loss: 0.504233  [19200/60000]
# loss: 0.413252  [25600/60000]
# loss: 0.421190  [32000/60000]
# loss: 0.447219  [38400/60000]
# loss: 0.630578  [44800/60000]
# loss: 0.567498  [51200/60000]
# loss: 0.390186  [57600/60000]
# Test Error:
#  Accuracy: 83.5%, Avg loss: 0.460203
#
# Epoch 73
# -------------------------------
# loss: 0.297565  [    0/60000]
# loss: 0.471895  [ 6400/60000]
# loss: 0.277457  [12800/60000]
# loss: 0.502826  [19200/60000]
# loss: 0.411165  [25600/60000]
# loss: 0.419896  [32000/60000]
# loss: 0.445777  [38400/60000]
# loss: 0.628802  [44800/60000]
# loss: 0.566198  [51200/60000]
# loss: 0.389330  [57600/60000]
# Test Error:
#  Accuracy: 83.6%, Avg loss: 0.459191
#
# Epoch 74
# -------------------------------
# loss: 0.295783  [    0/60000]
# loss: 0.470400  [ 6400/60000]
# loss: 0.276373  [12800/60000]
# loss: 0.501446  [19200/60000]
# loss: 0.409083  [25600/60000]
# loss: 0.418572  [32000/60000]
# loss: 0.444379  [38400/60000]
# loss: 0.627123  [44800/60000]
# loss: 0.564986  [51200/60000]
# loss: 0.388530  [57600/60000]
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.458204
#
# Epoch 75
# -------------------------------
# loss: 0.294017  [    0/60000]
# loss: 0.468873  [ 6400/60000]
# loss: 0.275339  [12800/60000]
# loss: 0.500075  [19200/60000]
# loss: 0.407078  [25600/60000]
# loss: 0.417216  [32000/60000]
# loss: 0.443057  [38400/60000]
# loss: 0.625615  [44800/60000]
# loss: 0.563858  [51200/60000]
# loss: 0.387831  [57600/60000]
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.457234
#
# Epoch 76
# -------------------------------
# loss: 0.292346  [    0/60000]
# loss: 0.467359  [ 6400/60000]
# loss: 0.274317  [12800/60000]
# loss: 0.498749  [19200/60000]
# loss: 0.405056  [25600/60000]
# loss: 0.415945  [32000/60000]
# loss: 0.441734  [38400/60000]
# loss: 0.624137  [44800/60000]
# loss: 0.562698  [51200/60000]
# loss: 0.387106  [57600/60000]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.456284
#
# Epoch 77
# -------------------------------
# loss: 0.290788  [    0/60000]
# loss: 0.465845  [ 6400/60000]
# loss: 0.273321  [12800/60000]
# loss: 0.497468  [19200/60000]
# loss: 0.403040  [25600/60000]
# loss: 0.414685  [32000/60000]
# loss: 0.440395  [38400/60000]
# loss: 0.622653  [44800/60000]
# loss: 0.561534  [51200/60000]
# loss: 0.386373  [57600/60000]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.455350
#
# Epoch 78
# -------------------------------
# loss: 0.289289  [    0/60000]
# loss: 0.464337  [ 6400/60000]
# loss: 0.272353  [12800/60000]
# loss: 0.496193  [19200/60000]
# loss: 0.401067  [25600/60000]
# loss: 0.413475  [32000/60000]
# loss: 0.439063  [38400/60000]
# loss: 0.621202  [44800/60000]
# loss: 0.560456  [51200/60000]
# loss: 0.385601  [57600/60000]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.454428
#
# Epoch 79
# -------------------------------
# loss: 0.287794  [    0/60000]
# loss: 0.462793  [ 6400/60000]
# loss: 0.271386  [12800/60000]
# loss: 0.494957  [19200/60000]
# loss: 0.399188  [25600/60000]
# loss: 0.412271  [32000/60000]
# loss: 0.437843  [38400/60000]
# loss: 0.619619  [44800/60000]
# loss: 0.559392  [51200/60000]
# loss: 0.384892  [57600/60000]
# Test Error:
#  Accuracy: 83.8%, Avg loss: 0.453526
#
# Epoch 80
# -------------------------------
# loss: 0.286316  [    0/60000]
# loss: 0.461298  [ 6400/60000]
# loss: 0.270450  [12800/60000]
# loss: 0.493768  [19200/60000]
# loss: 0.397280  [25600/60000]
# loss: 0.411071  [32000/60000]
# loss: 0.436633  [38400/60000]
# loss: 0.618092  [44800/60000]
# loss: 0.558251  [51200/60000]
# loss: 0.384200  [57600/60000]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.452639
#
# Epoch 81
# -------------------------------
# loss: 0.284928  [    0/60000]
# loss: 0.459832  [ 6400/60000]
# loss: 0.269548  [12800/60000]
# loss: 0.492566  [19200/60000]
# loss: 0.395386  [25600/60000]
# loss: 0.409867  [32000/60000]
# loss: 0.435423  [38400/60000]
# loss: 0.616577  [44800/60000]
# loss: 0.557087  [51200/60000]
# loss: 0.383562  [57600/60000]
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.451772
#
# Epoch 82
# -------------------------------
# loss: 0.283560  [    0/60000]
# loss: 0.458381  [ 6400/60000]
# loss: 0.268699  [12800/60000]
# loss: 0.491366  [19200/60000]
# loss: 0.393488  [25600/60000]
# loss: 0.408722  [32000/60000]
# loss: 0.434202  [38400/60000]
# loss: 0.615196  [44800/60000]
# loss: 0.555974  [51200/60000]
# loss: 0.382976  [57600/60000]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.450909
#
# Epoch 83
# -------------------------------
# loss: 0.282234  [    0/60000]
# loss: 0.456922  [ 6400/60000]
# loss: 0.267867  [12800/60000]
# loss: 0.490175  [19200/60000]
# loss: 0.391642  [25600/60000]
# loss: 0.407618  [32000/60000]
# loss: 0.432989  [38400/60000]
# loss: 0.613830  [44800/60000]
# loss: 0.554786  [51200/60000]
# loss: 0.382398  [57600/60000]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.450067
#
# Epoch 84
# -------------------------------
# loss: 0.280924  [    0/60000]
# loss: 0.455496  [ 6400/60000]
# loss: 0.267071  [12800/60000]
# loss: 0.489040  [19200/60000]
# loss: 0.389795  [25600/60000]
# loss: 0.406527  [32000/60000]
# loss: 0.431847  [38400/60000]
# loss: 0.612478  [44800/60000]
# loss: 0.553580  [51200/60000]
# loss: 0.381834  [57600/60000]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.449232
#
# Epoch 85
# -------------------------------
# loss: 0.279681  [    0/60000]
# loss: 0.454107  [ 6400/60000]
# loss: 0.266275  [12800/60000]
# loss: 0.487886  [19200/60000]
# loss: 0.387961  [25600/60000]
# loss: 0.405498  [32000/60000]
# loss: 0.430693  [38400/60000]
# loss: 0.611146  [44800/60000]
# loss: 0.552443  [51200/60000]
# loss: 0.381289  [57600/60000]
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.448403
#
# Epoch 86
# -------------------------------
# loss: 0.278481  [    0/60000]
# loss: 0.452735  [ 6400/60000]
# loss: 0.265493  [12800/60000]
# loss: 0.486811  [19200/60000]
# loss: 0.386222  [25600/60000]
# loss: 0.404475  [32000/60000]
# loss: 0.429502  [38400/60000]
# loss: 0.609839  [44800/60000]
# loss: 0.551290  [51200/60000]
# loss: 0.380794  [57600/60000]
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.447590
#
# Epoch 87
# -------------------------------
# loss: 0.277273  [    0/60000]
# loss: 0.451364  [ 6400/60000]
# loss: 0.264733  [12800/60000]
# loss: 0.485699  [19200/60000]
# loss: 0.384517  [25600/60000]
# loss: 0.403452  [32000/60000]
# loss: 0.428304  [38400/60000]
# loss: 0.608544  [44800/60000]
# loss: 0.550195  [51200/60000]
# loss: 0.380295  [57600/60000]
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.446785
#
# Epoch 88
# -------------------------------
# loss: 0.276117  [    0/60000]
# loss: 0.449967  [ 6400/60000]
# loss: 0.264002  [12800/60000]
# loss: 0.484551  [19200/60000]
# loss: 0.382785  [25600/60000]
# loss: 0.402465  [32000/60000]
# loss: 0.427162  [38400/60000]
# loss: 0.607356  [44800/60000]
# loss: 0.549029  [51200/60000]
# loss: 0.379841  [57600/60000]
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.445996
#
# Epoch 89
# -------------------------------
# loss: 0.274989  [    0/60000]
# loss: 0.448602  [ 6400/60000]
# loss: 0.263281  [12800/60000]
# loss: 0.483398  [19200/60000]
# loss: 0.381131  [25600/60000]
# loss: 0.401509  [32000/60000]
# loss: 0.426013  [38400/60000]
# loss: 0.606191  [44800/60000]
# loss: 0.547877  [51200/60000]
# loss: 0.379393  [57600/60000]
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.445211
#
# Epoch 90
# -------------------------------
# loss: 0.273950  [    0/60000]
# loss: 0.447235  [ 6400/60000]
# loss: 0.262619  [12800/60000]
# loss: 0.482165  [19200/60000]
# loss: 0.379469  [25600/60000]
# loss: 0.400557  [32000/60000]
# loss: 0.424780  [38400/60000]
# loss: 0.604999  [44800/60000]
# loss: 0.546725  [51200/60000]
# loss: 0.378911  [57600/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.444439
#
# Epoch 91
# -------------------------------
# loss: 0.272862  [    0/60000]
# loss: 0.445917  [ 6400/60000]
# loss: 0.261960  [12800/60000]
# loss: 0.480986  [19200/60000]
# loss: 0.377848  [25600/60000]
# loss: 0.399596  [32000/60000]
# loss: 0.423580  [38400/60000]
# loss: 0.603824  [44800/60000]
# loss: 0.545592  [51200/60000]
# loss: 0.378433  [57600/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.443675
#
# Epoch 92
# -------------------------------
# loss: 0.271834  [    0/60000]
# loss: 0.444623  [ 6400/60000]
# loss: 0.261315  [12800/60000]
# loss: 0.479777  [19200/60000]
# loss: 0.376221  [25600/60000]
# loss: 0.398621  [32000/60000]
# loss: 0.422320  [38400/60000]
# loss: 0.602589  [44800/60000]
# loss: 0.544542  [51200/60000]
# loss: 0.377952  [57600/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.442918
#
# Epoch 93
# -------------------------------
# loss: 0.270879  [    0/60000]
# loss: 0.443332  [ 6400/60000]
# loss: 0.260707  [12800/60000]
# loss: 0.478583  [19200/60000]
# loss: 0.374620  [25600/60000]
# loss: 0.397677  [32000/60000]
# loss: 0.421066  [38400/60000]
# loss: 0.601332  [44800/60000]
# loss: 0.543452  [51200/60000]
# loss: 0.377461  [57600/60000]
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.442164
#
# Epoch 94
# -------------------------------
# loss: 0.269889  [    0/60000]
# loss: 0.441990  [ 6400/60000]
# loss: 0.260091  [12800/60000]
# loss: 0.477373  [19200/60000]
# loss: 0.373054  [25600/60000]
# loss: 0.396697  [32000/60000]
# loss: 0.419886  [38400/60000]
# loss: 0.600126  [44800/60000]
# loss: 0.542350  [51200/60000]
# loss: 0.377015  [57600/60000]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.441420
#
# Epoch 95
# -------------------------------
# loss: 0.268915  [    0/60000]
# loss: 0.440729  [ 6400/60000]
# loss: 0.259479  [12800/60000]
# loss: 0.476188  [19200/60000]
# loss: 0.371471  [25600/60000]
# loss: 0.395684  [32000/60000]
# loss: 0.418753  [38400/60000]
# loss: 0.598928  [44800/60000]
# loss: 0.541341  [51200/60000]
# loss: 0.376622  [57600/60000]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.440683
#
# Epoch 96
# -------------------------------
# loss: 0.267980  [    0/60000]
# loss: 0.439465  [ 6400/60000]
# loss: 0.258849  [12800/60000]
# loss: 0.474995  [19200/60000]
# loss: 0.369887  [25600/60000]
# loss: 0.394674  [32000/60000]
# loss: 0.417642  [38400/60000]
# loss: 0.597687  [44800/60000]
# loss: 0.540356  [51200/60000]
# loss: 0.376221  [57600/60000]
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.439954
#
# Epoch 97
# -------------------------------
# loss: 0.267101  [    0/60000]
# loss: 0.438198  [ 6400/60000]
# loss: 0.258235  [12800/60000]
# loss: 0.473812  [19200/60000]
# loss: 0.368297  [25600/60000]
# loss: 0.393629  [32000/60000]
# loss: 0.416526  [38400/60000]
# loss: 0.596454  [44800/60000]
# loss: 0.539439  [51200/60000]
# loss: 0.375826  [57600/60000]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.439227
#
# Epoch 98
# -------------------------------
# loss: 0.266289  [    0/60000]
# loss: 0.436943  [ 6400/60000]
# loss: 0.257669  [12800/60000]
# loss: 0.472643  [19200/60000]
# loss: 0.366766  [25600/60000]
# loss: 0.392555  [32000/60000]
# loss: 0.415427  [38400/60000]
# loss: 0.595262  [44800/60000]
# loss: 0.538474  [51200/60000]
# loss: 0.375415  [57600/60000]
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.438512
#
# Epoch 99
# -------------------------------
# loss: 0.265473  [    0/60000]
# loss: 0.435708  [ 6400/60000]
# loss: 0.257102  [12800/60000]
# loss: 0.471500  [19200/60000]
# loss: 0.365292  [25600/60000]
# loss: 0.391522  [32000/60000]
# loss: 0.414371  [38400/60000]
# loss: 0.594127  [44800/60000]
# loss: 0.537484  [51200/60000]
# loss: 0.375022  [57600/60000]
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.437804
#
# Epoch 100
# -------------------------------
# loss: 0.264696  [    0/60000]
# loss: 0.434473  [ 6400/60000]
# loss: 0.256587  [12800/60000]
# loss: 0.470333  [19200/60000]
# loss: 0.363803  [25600/60000]
# loss: 0.390508  [32000/60000]
# loss: 0.413326  [38400/60000]
# loss: 0.593024  [44800/60000]
# loss: 0.536502  [51200/60000]
# loss: 0.374649  [57600/60000]
# Test Error:
#  Accuracy: 84.5%, Avg loss: 0.437105
#
# Done!

# %% [markdown]
# ------------------------------------------------------------------------------------------

# %% [markdown]
# 모델 저장하기
# ------------------------------------------------------------------------------------------
# 모델을 저장하는 일반적인 방법은 (모델의 매개변수들을 포함하여) 내부 상태 사전(internal state dictionary)을
# 직렬화(serialize)하는 것이다.

# %%
torch.save(model.state_dict(), "model.pth")
print("Saved PyTorch Model State to model.pth")
# Out:
# Saved PyTorch Model State to model.pth

# %% [markdown]
# 모델 불러오기
# ------------------------------------------------------------------------------------------
#
# 모델을 불러오는 과정에는 모델 구조를 다시 만들고 상태 사전을 모델에 불러오는 과정이 포함된다.

# %%
model = NeuralNetwork()
model.load_state_dict(torch.load("model.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# 이제 이 모델을 사용해서 예측을 할 수 있다.

# %%
classes = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot",
]

model.eval()
x, y = test_data[0][0], test_data[0][1]
with torch.no_grad():
    pred = model(x)
    predicted, actual = classes[pred[0].argmax(0)], classes[y]
    print(f'Predicted: "{predicted}", Actual: "{actual}"')
# Out:
# Predicted: "Ankle boot", Actual: "Ankle boot"
